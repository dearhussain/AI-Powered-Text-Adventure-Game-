# %% [markdown]
# Project Name: **AI Storytelling Adventure**
#
# Project Description:
# `This project creates an interactive AI-powered storytelling game using a deep learning model (LSTM) trained on Alice’s Adventures in Wonderland. The AI predicts and generates the next part of the story based on user input, making the game fun and dynamic.
# The model learns how words connect, ensuring smooth and meaningful storytelling. The game is built with Streamlit/Flask, so users can play it online easily.
# This project highlights AI, NLP, and Deep Learning, making it a great addition to a data science portfolio.
# `
#
# Date: 13/3/2025

# %% [markdown]
# # Scraping the Book

# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL of the book on Project Gutenberg
BOOK_URL = "https://www.gutenberg.org/files/11/11-0.txt"

# %%
# function to scrap and clean the text
def scrape_book(url):
    response = requests.get(url)
    response.encoding = "utf-8"  # Ensure correct text encoding

    if response.status_code == 200:
        text = response.text

        # Remove Gutenberg's header and footer
        start_marker = "*** START OF THIS PROJECT GUTENBERG EBOOK ALICE’S ADVENTURES ***"
        end_marker = "*** END OF THIS PROJECT GUTENBERG EBOOK ALICE’S ADVENTURES ***"

        start_idx = text.find(start_marker) + len(start_marker)
        end_idx = text.find(end_marker)

        if start_idx != -1 and end_idx != -1:
            cleaned_text = text[start_idx:end_idx].strip()
        else:
            cleaned_text = text  # Fallback to full text if markers not found

        # Save to a file
        with open("alice_wonderland.txt", "w", encoding="utf-8") as file:
            file.write(cleaned_text)

        print("✅ Book scraped and saved as 'alice_wonderland.txt'")
    else:
        print("❌ Failed to fetch the book. Check the URL.")

# %%
# run the function
scrape_book(BOOK_URL)
# Out:
# ✅ Book scraped and saved as 'alice_wonderland.txt'

# %%
print("✅ Book Scraping complete! Ready for Text Preprocessing.")
# Out:
# ✅ Book Scraping complete! Ready for Text Preprocessing.

# %% [markdown]
# # PreProcess The Text

# %%
# Import some neccessary libraries
import numpy as np
import pandas as pd

import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re

# %%
# load the clean text file in lower case letter
with open("alice_wonderland.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# %%
# Calculate one third of the text length
# half_length = len(text) // 2

# # Slice the text to keep only the first one third
# text = text[:half_length]

# # because of ram overloading

# %%
# Remove punctuation
text = re.sub(r'[^\w\s]', '', text)

# Replace multiple spaces with a single space
text = re.sub(r'\s+', ' ', text)

# Remove numbers (if they are not relevant)
text = re.sub(r'\d+', '', text)

# Strip leading and trailing whitespace
text = text.strip()

# Remove non-ASCII characters (if any)
text = re.sub(r'[^\x00-\x7F]+', '', text)

# %%
# Tokenize the text
tokenizer = Tokenizer(num_words=10000)  # Limit vocabulary size
tokenizer.fit_on_texts([text])

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('start', 1),
#              ('of', 511),
#              ('the', 1640),
#              ('project', 2),
#              ('gutenberg', 2),
#              ('ebook', 2),
#              ('illustration', 1),
#              ('alices', 13),
#              ('adventures', 6),
#              ('in', 367),
#              ('wonderland', 3),
#              ('by', 57),
#              ('lewis', 1),
#              ('carroll', 1),
#              ('millennium', 1),
#              ('fulcrum', 1),
#              ('edition', 1),
#              ('contents', 1),
#              ('chapter', 24),
#              ('i', 402),
#              ('down', 102),
#              ('rabbithole', 4),
#              ('ii', 3),
#              ('pool', 11),
#              ('tears', 12),
#              ('iii', 2),
#              ('a', 632),
#              ('caucusrace', 4),
#              ('and', 846),
#              ('long', 33),
#              ('tale', 5),
#              ('iv', 2),
#              ('rabbit', 44),
#              ('sends', 2),
#              ('little', 129),
#              ('bill', 13),
#              ('v', 2),
#              ('advice', 3),
#              ('from', 37),
#              ('caterpillar', 28),
#              ('vi', 2),
#              ('pig', 9),
#              ('pepper', 8),
#              ('vii', 2),
#              ('mad', 15),
#              ('teaparty', 3),
#              ('viii', 2),
#              ('queens', 9),
#              ('croquetground', 4),
#              ('ix', 2),
#              ('mock', 57),
#              ('turtles', 5),
#              ('story', 9),
#              ('x', 2),
#              ('lobster', 8),
#              ('quadrille', 5),
#              ('xi', 2),
#              ('who', 62),
#              ('stole', 3),
#              ('tarts', 8),
#              ('xii', 2),
#              ('evidence', 8),
#              ('alice', 385),
#              ('was', 357),
#              ('beginning', 13),
#              ('to', 721),
#              ('get', 46),
#              ('very', 144),
#              ('tired', 7),
#              ('sitting', 10),
#              ('her', 248),
#              ('sister', 8),
#              ('on', 193),
#              ('bank', 2),
#              ('having', 10),
#              ('nothing', 34),
#              ('do', 80),
#              ('once', 32),
#              ('or', 76),
#              ('twice', 5),
#              ('she', 538),
#              ('had', 178),
#              ('peeped', 3),
#              ('into', 67),
#              ('book', 7),
#              ('reading', 3),
#              ('but', 164),
#              ('it', 527),
#              ('no', 87),
#              ('pictures', 4),
#              ('conversations', 2),
#              ('what', 136),
#              ('is', 102),
#              ('use', 18),
#              ('thought', 74),
#              ('without', 25),
#              ('so', 151),
#              ('considering', 3),
#              ('own', 10),
#              ('mind', 10),
#              ('as', 262),
#              ('well', 60),
#              ('could', 77),
#              ('for', 153),
#              ('hot', 5),
#              ('day', 25),
#              ('made', 30),
#              ('feel', 8),
#              ('sleepy', 5),
#              ('stupid', 6),
#              ('whether', 11),
#              ('pleasure', 2),
#              ('making', 8),
#              ('daisychain', 1),
#              ('would', 83),
#              ('be', 146),
#              ('worth', 4),
#              ('trouble', 6),
#              ('getting', 22),
#              ('up', 98),
#              ('picking', 2),
#              ('daisies', 1),
#              ('when', 79),
#              ('suddenly', 13),
#              ('white', 30),
#              ('with', 181),
#              ('pink', 1),
#              ('eyes', 27),
#              ('ran', 16),
#              ('close', 13),
#              ('there', 75),
#              ('remarkable', 2),
#              ('that', 277),
#              ('nor', 3),
#              ('did', 62),
#              ('think', 53),
#              ('much', 51),
#              ('out', 113),
#              ('way', 53),
#              ('hear', 14),
#              ('say', 50),
#              ('itself', 14),
#              ('oh', 38),
#              ('dear', 29),
#              ('shall', 25),
#              ('late', 6),
#              ('over', 40),
#              ('afterwards', 2),
#              ('occurred', 2),
#              ('ought', 14),
#              ('have', 80),
#              ('wondered', 1),
#              ('at', 209),
#              ('this', 134),
#              ('time', 68),
#              ('all', 180),
#              ('seemed', 27),
#              ('quite', 55),
#              ('natural', 4),
#              ('actually', 1),
#              ('took', 24),
#              ('watch', 8),
#              ('its', 111),
#              ('waistcoatpocket', 2),
#              ('looked', 45),
#              ('then', 91),
#              ('hurried', 11),
#              ('started', 2),
#              ('feet', 19),
#              ('flashed', 1),
#              ('across', 5),
#              ('never', 45),
#              ('before', 38),
#              ('seen', 14),
#              ('either', 10),
#              ('take', 21),
#              ('burning', 1),
#              ('curiosity', 5),
#              ('field', 1),
#              ('after', 42),
#              ('fortunately', 1),
#              ('just', 51),
#              ('see', 66),
#              ('pop', 1),
#              ('large', 33),
#              ('under', 16),
#              ('hedge', 2),
#              ('another', 22),
#              ('moment', 29),
#              ('went', 83),
#              ('how', 64),
#              ('world', 7),
#              ('again', 83),
#              ('straight', 2),
#              ('like', 85),
#              ('tunnel', 1),
#              ('some', 51),
#              ('dipped', 2),
#              ('not', 144),
#              ('about', 94),
#              ('stopping', 1),
#              ('herself', 83),
#              ('found', 32),
#              ('falling', 2),
#              ('deep', 7),
#              ('fell', 6),
#              ('slowly', 8),
#              ('plenty', 2),
#              ('look', 28),
#              ('wonder', 18),
#              ('going', 27),
#              ('happen', 8),
#              ('next', 30),
#              ('first', 49),
#              ('tried', 19),
#              ('make', 26),
#              ('coming', 9),
#              ('too', 26),
#              ('dark', 3),
#              ('anything', 19),
#              ('sides', 4),
#              ('noticed', 8),
#              ('they', 127),
#              ('were', 87),
#              ('filled', 3),
#              ('cupboards', 2),
#              ('bookshelves', 1),
#              ('here', 48),
#              ('saw', 14),
#              ('maps', 1),
#              ('hung', 1),
#              ('upon', 26),
#              ('pegs', 1),
#              ('jar', 2),
#              ('one', 101),
#              ('shelves', 1),
#              ('passed', 5),
#              ('labelled', 1),
#              ('orange', 1),
#              ('marmalade', 1),
#              ('great', 39),
#              ('disappointment', 1),
#              ('empty', 1),
#              ('drop', 1),
#              ('fear', 4),
#              ('killing', 1),
#              ('somebody', 7),
#              ('underneath', 2),
#              ('managed', 4),
#              ('put', 31),
#              ('past', 1),
#              ('such', 41),
#              ('fall', 7),
#              ('tumbling', 2),
#              ('stairs', 3),
#              ('brave', 1),
#              ('theyll', 4),
#              ('me', 68),
#              ('home', 5),
#              ('why', 39),
#              ('wouldnt', 13),
#              ('even', 18),
#              ('if', 94),
#              ('off', 73),
#              ('top', 8),
#              ('house', 18),
#              ('which', 49),
#              ('likely', 5),
#              ('true', 4),
#              ('come', 46),
#              ('an', 57),
#              ('end', 19),
#              ('many', 12),
#              ('miles', 3),
#              ('ive', 34),
#              ('fallen', 4),
#              ('said', 462),
#              ('aloud', 5),
#              ('must', 44),
#              ('somewhere', 3),
#              ('near', 15),
#              ('centre', 1),
#              ('earth', 4),
#              ('let', 17),
#              ('four', 6),
#              ('thousand', 2),
#              ('you', 361),
#              ('learnt', 2),
#              ('several', 4),
#              ('things', 28),
#              ('sort', 20),
#              ('lessons', 10),
#              ('schoolroom', 1),
#              ('though', 11),
#              ('good', 24),
#              ('opportunity', 8),
#              ('showing', 2),
#              ('knowledge', 3),
#              ('listen', 7),
#              ('still', 13),
#              ('practice', 1),
#              ('yes', 13),
#              ('thats', 33),
#              ('right', 31),
#              ('distancebut', 1),
#              ('latitude', 2),
#              ('longitude', 2),
#              ('got', 45),
#              ('idea', 15),
#              ('nice', 6),
#              ('grand', 3),
#              ('words', 21),
#              ('presently', 2),
#              ('began', 58),
#              ('through', 14),
#              ('funny', 3),
#              ('itll', 8),
#              ('seem', 8),
#              ('among', 12),
#              ('people', 13),
#              ('walk', 5),
#              ('their', 52),
#              ('heads', 11),
#              ('downward', 1),
#              ('antipathies', 1),
#              ('rather', 25),
#              ('glad', 11),
#              ('listening', 3),
#              ('didnt', 14),
#              ('sound', 4),
#              ('word', 10),
#              ('ask', 11),
#              ('them', 84),
#              ('name', 10),
#              ('country', 1),
#              ('know', 85),
#              ('please', 19),
#              ('maam', 1),
#              ('new', 5),
#              ('zealand', 1),
#              ('australia', 1),
#              ('curtsey', 1),
#              ('spokefancy', 1),
#              ('curtseying', 1),
#              ('youre', 23),
#              ('air', 14),
#              ('manage', 7),
#              ('ignorant', 1),
#              ('girl', 4),
#              ('shell', 3),
#              ('asking', 5),
#              ('perhaps', 17),
#              ('written', 6),
#              ('else', 10),
#              ('soon', 25),
#              ('talking', 17),
#              ('dinahll', 2),
#              ('miss', 4),
#              ('tonight', 1),
#              ('should', 27),
#              ('dinah', 11),
#              ('cat', 35),
#              ('hope', 3),
#              ('remember', 14),
#              ('saucer', 1),
#              ('milk', 1),
#              ('teatime', 2),
#              ('my', 58),
#              ('wish', 21),
#              ('are', 53),
#              ('mice', 3),
#              ('im', 57),
#              ('afraid', 12),
#              ('might', 28),
#              ('catch', 3),
#              ('bat', 3),
#              ('mouse', 38),
#              ('cats', 15),
#              ('eat', 18),
#              ('bats', 4),
#              ('saying', 15),
#              ('dreamy', 1),
#              ('sometimes', 5),
#              ('couldnt', 9),
#              ('answer', 9),
#              ('question', 17),
#              ('matter', 9),
#              ('felt', 23),
#              ('dozing', 1),
#              ('begun', 7),
#              ('dream', 7),
#              ('walking', 5),
#              ('hand', 20),
#              ('earnestly', 2),
#              ('now', 57),
#              ('tell', 31),
#              ('truth', 1),
#              ('ever', 22),
#              ('thump', 2),
#              ('came', 40),
#              ('heap', 1),
#              ('sticks', 1),
#              ('dry', 8),
#              ('leaves', 6),
#              ('bit', 16),
#              ('hurt', 3),
#              ('jumped', 6),
#              ('overhead', 1),
#              ('passage', 4),
#              ('sight', 10),
#              ('hurrying', 1),
#              ('lost', 3),
#              ('away', 25),
#              ('wind', 2),
#              ('turned', 16),
#              ('corner', 3),
#              ('ears', 5),
#              ('whiskers', 3),
#              ('behind', 13),
#              ('longer', 3),
#              ('low', 14),
#              ('hall', 9),
#              ('lit', 1),
#              ('row', 2),
#              ('lamps', 1),
#              ('hanging', 3),
#              ('roof', 6),
#              ('doors', 2),
#              ('round', 41),
#              ('locked', 1),
#              ('been', 38),
#              ('side', 17),
#              ('other', 39),
#              ('trying', 14),
#              ('every', 12),
#              ('door', 29),
#              ('walked', 10),
#              ('sadly', 5),
#              ('middle', 7),
#              ('wondering', 7),
#              ('threelegged', 2),
#              ('table', 18),
#              ('solid', 1),
#              ('glass', 9),
#              ('except', 4),
#              ('tiny', 4),
#              ('golden', 7),
#              ('key', 9),
#              ('belong', 1),
#              ('alas', 4),
#              ('locks', 2),
#              ('small', 10),
#              ('any', 39),
#              ('rate', 9),
#              ('open', 7),
#              ('however', 20),
#              ('second', 4),
#              ('curtain', 1),
#              ('fifteen', 1),
#              ('inches', 6),
#              ('high', 16),
#              ('lock', 1),
#              ('delight', 3),
#              ('fitted', 1),
#              ('opened', 10),
#              ('led', 4),
#              ('larger', 7),
#              ('than', 24),
#              ('rathole', 1),
#              ('knelt', 1),
#              ('along', 5),
#              ('loveliest', 1),
#              ('garden', 15),
#              ('longed', 2),
#              ('wander', 1),
#              ('those', 10),
#              ('beds', 1),
#              ('bright', 7),
#              ('flowers', 2),
#              ('cool', 2),
#              ('fountains', 2),
#              ('head', 48),
#              ('doorway', 1),
#              ('go', 50),
#              ('poor', 27),
#              ('shoulders', 4),
#              ('shut', 5),
#              ('telescope', 3),
#              ('only', 49),
#              ('knew', 15),
#              ('begin', 13),
#              ('outoftheway', 3),
#              ('happened', 7),
#              ('lately', 1),
#              ('few', 9),
#              ('indeed', 16),
#              ('really', 13),
#              ('impossible', 3),
#              ('waiting', 9),
#              ('back', 38),
#              ('half', 21),
#              ('hoping', 3),
#              ('find', 21),
#              ('rules', 3),
#              ('shutting', 2),
#              ('telescopes', 1),
#              ('bottle', 10),
#              ('certainly', 14),
#              ('neck', 7),
#              ('paper', 4),
#              ('label', 2),
#              ('drink', 7),
#              ('beautifully', 2),
#              ('printed', 1),
#              ('letters', 1),
#              ('wise', 2),
#              ('hurry', 11),
#              ('ill', 33),
#              ('marked', 6),
#              ('poison', 3),
#              ('read', 11),
#              ('histories', 1),
#              ('children', 10),
#              ('burnt', 1),
#              ('eaten', 1),
#              ('wild', 2),
#              ('beasts', 2),
#              ('unpleasant', 2),
#              ('because', 15),
#              ('simple', 5),
#              ('friends', 2),
#              ('taught', 4),
#              ('redhot', 1),
#              ('poker', 1),
#              ('will', 31),
#              ('burn', 2),
#              ('hold', 9),
#              ('cut', 5),
#              ('your', 62),
#              ('finger', 5),
#              ('deeply', 4),
#              ('knife', 2),
#              ('usually', 2),
#              ('bleeds', 1),
#              ('forgotten', 6),
#              ('almost', 6),
#              ('certain', 3),
#              ('disagree', 1),
#              ('sooner', 2),
#              ('later', 3),
#              ('ventured', 4),
#              ('taste', 2),
#              ('finding', 3),
#              ('fact', 8),
#              ('mixed', 2),
#              ('flavour', 1),
#              ('cherrytart', 1),
#              ('custard', 1),
#              ('pineapple', 1),
#              ('roast', 1),
#              ('turkey', 1),
#              ('toffee', 1),
#              ('buttered', 1),
#              ('toast', 1),
#              ('finished', 12),
#              ('curious', 19),
#              ('feeling', 7),
#              ('ten', 6),
#              ('face', 14),
#              ('brightened', 2),
#              ('size', 13),
#              ('lovely', 2),
#              ('waited', 11),
#              ('minutes', 11),
#              ('shrink', 1),
#              ('further', 3),
#              ('nervous', 5),
#              ('altogether', 5),
#              ('candle', 3),
#              ('fancy', 5),
#              ('flame', 1),
#              ('blown', 1),
#              ('thing', 49),
#              ('while', 24),
#              ('more', 48),
#              ('decided', 3),
#              ('possibly', 3),
#              ('reach', 4),
#              ('plainly', 1),
#              ('best', 12),
#              ('climb', 1),
#              ('legs', 3),
#              ('slippery', 1),
#              ('sat', 17),
#              ('cried', 20),
#              ('theres', 24),
#              ('crying', 2),
#              ('sharply', 4),
#              ('advise', 1),
#              ('leave', 9),
#              ('minute', 21),
#              ('generally', 7),
#              ('gave', 15),
#              ('seldom', 1),
#              ('followed', 8),
#              ('scolded', 1),
#              ('severely', 4),
#              ('bring', 3),
#              ('remembered', 5),
#              ('box', 4),
#              ('cheated', 1),
#              ('game', 12),
#              ('croquet', 6),
#              ('playing', 2),
#              ('against', 9),
#              ('child', 10),
#              ('fond', 3),
#              ('pretending', 1),
#              ('two', 39),
#              ('pretend', 1),
#              ('hardly', 12),
#              ('enough', 17),
#              ('left', 14),
#              ('respectable', 1),
#              ('person', 4),
#              ('eye', 7),
#              ('lying', 8),
#              ('cake', 3),
#              ('currants', 1),
#              ('makes', 11),
#              ('grow', 13),
#              ('can', 34),
#              ('smaller', 3),
#              ('creep', 1),
#              ('dont', 60),
#              ('care', 4),
#              ('happens', 5),
#              ('ate', 1),
#              ('anxiously', 14),
#              ('holding', 3),
#              ('growing', 11),
#              ('surprised', 7),
#              ('remained', 3),
#              ('same', 24),
#              ('sure', 24),
#              ('eats', 1),
#              ('expecting', 3),
#              ('dull', 3),
#              ('life', 11),
#              ('common', 1),
#              ('set', 14),
#              ('work', 8),
#              ('curiouser', 2),
#              ('forgot', 2),
#              ('speak', 14),
#              ('english', 6),
#              ('opening', 3),
#              ('largest', 1),
#              ('goodbye', 1),
#              ('far', 13),
#              ('shoes', 7),
#              ('stockings', 1),
#              ('dears', 3),
#              ('shant', 6),
#              ('able', 1),
#              ('deal', 12),
#              ('myself', 7),
#              ('canbut', 1),
#              ('kind', 7),
#              ('wont', 24),
#              ('want', 9),
#              ('give', 12),
#              ('pair', 5),
#              ('boots', 4),
#              ('christmas', 1),
#              ('planning', 1),
#              ('carrier', 1),
#              ('sending', 2),
#              ('presents', 2),
#              ('ones', 2),
#              ('odd', 1),
#              ('directions', 3),
#              ('foot', 10),
#              ('esq', 1),
#              ('hearthrug', 1),
#              ('fender', 1),
#              ('love', 3),
#              ('nonsense', 7),
#              ('struck', 2),
#              ('nine', 5),
#              ('hopeless', 1),
#              ('cry', 3),
#              ('ashamed', 2),
#              ('yourself', 10),
#              ('stop', 6),
#              ('shedding', 1),
#              ('gallons', 1),
#              ('until', 5),
#              ('reaching', 1),
#              ('heard', 30),
#              ('pattering', 3),
#              ('distance', 7),
#              ('hastily', 16),
#              ('dried', 1),
#              ('returning', 1),
#              ('splendidly', 1),
#              ('dressed', 1),
#              ('kid', 5),
#              ('gloves', 10),
#              ('fan', 10),
#              ('he', 120),
#              ('trotting', 2),
#              ('muttering', 3),
#              ('himself', 6),
#              ('duchess', 39),
#              ('savage', 4),
#              ('kept', 13),
#              ('desperate', 1),
#              ('ready', 8),
#              ('help', 9),
#              ('timid', 3),
#              ('voice', 47),
#              ('sir', 7),
#              ('violently', 4),
#              ('dropped', 5),
#              ('skurried', 1),
#              ('darkness', 1),
#              ('hard', 8),
#              ('fanning', 1),
#              ('queer', 10),
#              ('everything', 10),
#              ('today', 4),
#              ('yesterday', 3),
#              ('usual', 5),
#              ('changed', 8),
#              ('night', 3),
#              ('morning', 5),
#              ('different', 9),
#              ('am', 15),
#              ('ah', 5),
#              ('puzzle', 1),
#              ('thinking', 11),
#              ('age', 4),
#              ('ada', 1),
#              ('hair', 7),
#              ('goes', 7),
#              ('ringlets', 2),
#              ('mine', 8),
#              ('doesnt', 16),
#              ('cant', 28),
#              ('mabel', 4),
#              ('sorts', 3),
#              ('knows', 2),
#              ('besides', 4),
#              ('shes', 7),
#              ('andoh', 2),
#              ('puzzling', 4),
#              ('try', 12),
#              ('used', 12),
#              ('times', 6),
#              ('five', 8),
#              ('twelve', 4),
#              ('six', 2),
#              ('thirteen', 1),
#              ('seven', 6),
#              ('isoh', 2),
#              ('twenty', 1),
#              ('multiplication', 1),
#              ('signify', 1),
#              ('lets', 5),
#              ('geography', 1),
#              ('london', 1),
#              ('capital', 4),
#              ('paris', 2),
#              ('rome', 1),
#              ('romeno', 1),
#              ('wrong', 5),
#              ('doth', 3),
#              ('crossed', 3),
#              ('hands', 12),
#              ('lap', 2),
#              ('repeat', 7),
#              ('sounded', 5),
#              ('hoarse', 3),
#              ('strange', 5),
#              ('crocodile', 1),
#              ('improve', 1),
#              ('his', 96),
#              ('shining', 1),
#              ('tail', 9),
#              ('pour', 1),
#              ('waters', 1),
#              ('nile', 1),
#              ('scale', 1),
#              ('cheerfully', 1),
#              ('seems', 5),
#              ('grin', 6),
#              ('neatly', 2),
#              ('spread', 3),
#              ('claws', 2),
#              ('welcome', 1),
#              ('fishes', 1),
#              ('gently', 3),
#              ('smiling', 2),
#              ('jaws', 2),
#              ('live', 8),
#              ('poky', 1),
#              ('toys', 1),
#              ('play', 8),
#              ('learn', 7),
#              ('stay', 5),
#              ('putting', 3),
#              ('being', 19),
#              ('till', 21),
#              ('elsebut', 1),
#              ('sudden', 5),
#              ('burst', 1),
#              ('alone', 4),
#              ('rabbits', 4),
#              ('done', 15),
#              ('measure', 1),
#              ('nearly', 11),
#              ('guess', 3),
#              ('shrinking', 4),
#              ('rapidly', 2),
#              ('cause', 3),
#              ('avoid', 1),
#              ('narrow', 2),
#              ('escape', 4),
#              ('frightened', 7),
#              ('change', 14),
#              ('existence', 1),
#              ('speed', 1),
#              ('worse', 3),
#              ('declare', 2),
#              ('bad', 2),
#              ('these', 14),
#              ('slipped', 3),
#              ('splash', 1),
#              ('chin', 7),
#              ('salt', 2),
#              ('water', 4),
#              ('somehow', 1),
#              ('sea', 13),
#              ('case', 5),
#              ('railway', 2),
#              ('seaside', 1),
#              ('general', 3),
#              ('conclusion', 2),
#              ('wherever', 2),
#              ('coast', 1),
#              ('number', 5),
#              ('bathing', 1),
#              ('machines', 1),
#              ('digging', 4),
#              ('sand', 1),
#              ('wooden', 1),
#              ('spades', 1),
#              ('lodging', 1),
#              ('houses', 1),
#              ('station', 1),
#              ('wept', 1),
#              ('hadnt', 8),
#              ('swam', 5),
#              ('punished', 1),
#              ('suppose', 14),
#              ('drowned', 1),
#              ('something', 18),
#              ('splashing', 2),
#              ('nearer', 5),
#              ('walrus', 1),
#              ('hippopotamus', 1),
#              ('talk', 14),
#              ('harm', 1),
#              ('o', 3),
#              ('swimming', 2),
#              ('speaking', 5),
#              ('brothers', 1),
#              ('latin', 1),
#              ('grammar', 1),
#              ('mouseof', 1),
#              ('mouseto', 1),
#              ('mousea', 1),
#              ('mouseo', 1),
#              ('inquisitively', 1),
#              ('wink', 2),
#              ('understand', 6),
#              ('daresay', 1),
#              ('french', 4),
#              ('william', 7),
#              ('conqueror', 2),
#              ('history', 7),
#              ('clear', 2),
#              ('notion', 3),
#              ('ago', 2),
#              ('est', 1),
#              ('ma', 2),
#              ('chatte', 1),
#              ('sentence', 6),
#              ('lessonbook', 1),
#              ('leap', 1),
#              ('quiver', 1),
#              ('fright', 2),
#              ('beg', 8),
#              ('pardon', 6),
#              ('animals', 5),
#              ('feelings', 2),
#              ('shrill', 5),
#              ('passionate', 1),
#              ('soothing', 1),
#              ('tone', 40),
#              ('angry', 5),
#              ('yet', 22),
#              ('show', 3),
#              ('our', 8),
#              ('youd', 10),
#              ('quiet', 2),
#              ('lazily', 1),
#              ('sits', 1),
#              ('purring', 2),
#              ('nicely', 2),
#              ('fire', 3),
#              ('licking', 1),
#              ('paws', 4),
#              ('washing', 3),
#              ('faceand', 1),
#              ('soft', 1),
#              ('nurseand', 1),
#              ('catching', 2),
#              ('miceoh', 1),
#              ('bristling', 1),
#              ('offended', 10),
#              ('we', 29),
#              ('trembling', 6),
#              ('subject', 6),
#              ('family', 1),
#              ('always', 12),
#              ('hated', 1),
#              ('nasty', 1),
#              ('vulgar', 1),
#              ('conversation', 9),
#              ('youare', 1),
#              ('fondofof', 1),
#              ('dogs', 4),
#              ('eagerly', 8),
#              ('dog', 2),
#              ('brighteyed', 1),
#              ('terrier', 1),
#              ('curly', 1),
#              ('brown', 2),
#              ('fetch', 7),
#              ('throw', 3),
#              ('sit', 8),
#              ('dinner', 2),
#              ('thingsi', 1),
#              ('themand', 2),
#              ('belongs', 2),
#              ('farmer', 1),
#              ('says', 4),
#              ('useful', 2),
#              ('hundred', 1),
#              ('pounds', 1),
#              ('kills', 1),
#              ('rats', 1),
#              ('sorrowful', 2),
#              ('commotion', 1),
#              ('called', 15),
#              ('softly', 1),
#              ('pale', 4),
#              ('passion', 3),
#              ('us', 14),
#              ('shore', 3),
#              ('youll', 6),
#              ('hate', 1),
#              ('crowded', 5),
#              ('birds', 9),
#              ('duck', 4),
#              ('dodo', 13),
#              ('lory', 7),
#              ('eaglet', 3),
#              ('creatures', 10),
#              ('whole', 13),
#              ('party', 8),
#              ('queerlooking', 1),
#              ('assembled', 2),
#              ('bankthe', 1),
#              ('draggled', 1),
#              ('feathers', 1),
#              ('fur', 3),
#              ('clinging', 1),
#              ('dripping', 1),
#              ('wet', 2),
#              ('cross', 1),
#              ('uncomfortable', 4),
#              ('course', 25),
#              ('consultation', 1),
#              ('familiarly', 1),
#              ('known', 1),
#              ('argument', 4),
#              ('last', 33),
#              ...])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'to': 3,
#  'a': 4,
#  'she': 5,
#  'it': 6,
#  'of': 7,
#  'said': 8,
#  'i': 9,
#  'alice': 10,
#  'in': 11,
#  'you': 12,
#  'was': 13,
#  'that': 14,
#  'as': 15,
#  'her': 16,
#  'at': 17,
#  'on': 18,
#  'with': 19,
#  'all': 20,
#  'had': 21,
#  'but': 22,
#  'for': 23,
#  'so': 24,
#  'be': 25,
#  'very': 26,
#  'not': 27,
#  'what': 28,
#  'this': 29,
#  'little': 30,
#  'they': 31,
#  'he': 32,
#  'out': 33,
#  'its': 34,
#  'down': 35,
#  'is': 36,
#  'one': 37,
#  'up': 38,
#  'his': 39,
#  'about': 40,
#  'if': 41,
#  'then': 42,
#  'no': 43,
#  'were': 44,
#  'like': 45,
#  'know': 46,
#  'them': 47,
#  'would': 48,
#  'went': 49,
#  'again': 50,
#  'herself': 51,
#  'do': 52,
#  'have': 53,
#  'when': 54,
#  'could': 55,
#  'or': 56,
#  'there': 57,
#  'thought': 58,
#  'off': 59,
#  'time': 60,
#  'me': 61,
#  'queen': 62,
#  'into': 63,
#  'see': 64,
#  'how': 65,
#  'who': 66,
#  'did': 67,
#  'your': 68,
#  'king': 69,
#  'well': 70,
#  'dont': 71,
#  'began': 72,
#  'my': 73,
#  'by': 74,
#  'mock': 75,
#  'an': 76,
#  'im': 77,
#  'now': 78,
#  'turtle': 79,
#  'quite': 80,
#  'hatter': 81,
#  'gryphon': 82,
#  'think': 83,
#  'way': 84,
#  'are': 85,
#  'their': 86,
#  'much': 87,
#  'just': 88,
#  'some': 89,
#  'say': 90,
#  'go': 91,
#  'first': 92,
#  'which': 93,
#  'only': 94,
#  'thing': 95,
#  'here': 96,
#  'head': 97,
#  'more': 98,
#  'voice': 99,
#  'get': 100,
#  'come': 101,
#  'looked': 102,
#  'never': 103,
#  'got': 104,
#  'rabbit': 105,
#  'must': 106,
#  'after': 107,
#  'such': 108,
#  'round': 109,
#  'him': 110,
#  'over': 111,
#  'came': 112,
#  'tone': 113,
#  'great': 114,
#  'why': 115,
#  'other': 116,
#  'any': 117,
#  'two': 118,
#  'duchess': 119,
#  'dormouse': 120,
#  'oh': 121,
#  'before': 122,
#  'mouse': 123,
#  'been': 124,
#  'back': 125,
#  'from': 126,
#  'cat': 127,
#  'nothing': 128,
#  'ive': 129,
#  'can': 130,
#  'long': 131,
#  'large': 132,
#  'thats': 133,
#  'ill': 134,
#  'last': 135,
#  'march': 136,
#  'once': 137,
#  'found': 138,
#  'put': 139,
#  'right': 140,
#  'tell': 141,
#  'will': 142,
#  'hare': 143,
#  'made': 144,
#  'white': 145,
#  'next': 146,
#  'heard': 147,
#  'looking': 148,
#  'dear': 149,
#  'moment': 150,
#  'door': 151,
#  'we': 152,
#  'replied': 153,
#  'caterpillar': 154,
#  'look': 155,
#  'things': 156,
#  'might': 157,
#  'cant': 158,
#  'eyes': 159,
#  'seemed': 160,
#  'going': 161,
#  'should': 162,
#  'poor': 163,
#  'make': 164,
#  'too': 165,
#  'upon': 166,
#  'three': 167,
#  'without': 168,
#  'day': 169,
#  'shall': 170,
#  'rather': 171,
#  'soon': 172,
#  'away': 173,
#  'course': 174,
#  'chapter': 175,
#  'took': 176,
#  'good': 177,
#  'than': 178,
#  'while': 179,
#  'theres': 180,
#  'same': 181,
#  'sure': 182,
#  'wont': 183,
#  'youre': 184,
#  'felt': 185,
#  'added': 186,
#  'getting': 187,
#  'another': 188,
#  'ever': 189,
#  'yet': 190,
#  'take': 191,
#  'words': 192,
#  'wish': 193,
#  'half': 194,
#  'find': 195,
#  'minute': 196,
#  'till': 197,
#  'sort': 198,
#  'hand': 199,
#  'however': 200,
#  'cried': 201,
#  'feet': 202,
#  'tried': 203,
#  'anything': 204,
#  'end': 205,
#  'please': 206,
#  'curious': 207,
#  'being': 208,
#  'old': 209,
#  'use': 210,
#  'wonder': 211,
#  'even': 212,
#  'house': 213,
#  'eat': 214,
#  'table': 215,
#  'something': 216,
#  'soup': 217,
#  'court': 218,
#  'let': 219,
#  'perhaps': 220,
#  'talking': 221,
#  'question': 222,
#  'side': 223,
#  'sat': 224,
#  'enough': 225,
#  'asked': 226,
#  'jury': 227,
#  'ran': 228,
#  'under': 229,
#  'bit': 230,
#  'turned': 231,
#  'high': 232,
#  'indeed': 233,
#  'hastily': 234,
#  'doesnt': 235,
#  'spoke': 236,
#  'mad': 237,
#  'near': 238,
#  'idea': 239,
#  'cats': 240,
#  'saying': 241,
#  'garden': 242,
#  'knew': 243,
#  'because': 244,
#  'gave': 245,
#  'am': 246,
#  'done': 247,
#  'called': 248,
#  'hear': 249,
#  'itself': 250,
#  'ought': 251,
#  'seen': 252,
#  'saw': 253,
#  'through': 254,
#  'didnt': 255,
#  'air': 256,
#  'remember': 257,
#  'low': 258,
#  'trying': 259,
#  'certainly': 260,
#  'face': 261,
#  'left': 262,
#  'anxiously': 263,
#  'set': 264,
#  'speak': 265,
#  'change': 266,
#  'these': 267,
#  'suppose': 268,
#  'talk': 269,
#  'us': 270,
#  'better': 271,
#  'silence': 272,
#  'both': 273,
#  'beautiful': 274,
#  'alices': 275,
#  'bill': 276,
#  'beginning': 277,
#  'suddenly': 278,
#  'close': 279,
#  'wouldnt': 280,
#  'still': 281,
#  'yes': 282,
#  'people': 283,
#  'behind': 284,
#  'begin': 285,
#  'really': 286,
#  'size': 287,
#  'grow': 288,
#  'far': 289,
#  'kept': 290,
#  'sea': 291,
#  'dodo': 292,
#  'whole': 293,
#  'where': 294,
#  'room': 295,
#  'gone': 296,
#  'may': 297,
#  'theyre': 298,
#  'cook': 299,
#  'dance': 300,
#  'tears': 301,
#  'many': 302,
#  'among': 303,
#  'afraid': 304,
#  'every': 305,
#  'finished': 306,
#  'best': 307,
#  'game': 308,
#  'hardly': 309,
#  'deal': 310,
#  'give': 311,
#  'try': 312,
#  'used': 313,
#  'hands': 314,
#  'always': 315,
#  'turning': 316,
#  'arm': 317,
#  'pigeon': 318,
#  'baby': 319,
#  'tea': 320,
#  'majesty': 321,
#  'pool': 322,
#  'whether': 323,
#  'hurried': 324,
#  'though': 325,
#  'heads': 326,
#  'glad': 327,
#  'ask': 328,
#  'dinah': 329,
#  'hurry': 330,
#  'read': 331,
#  'waited': 332,
#  'minutes': 333,
#  'makes': 334,
#  'growing': 335,
#  'life': 336,
#  'thinking': 337,
#  'nearly': 338,
#  'id': 339,
#  'wasnt': 340,
#  'keep': 341,
#  'sitting': 342,
#  'having': 343,
#  'own': 344,
#  'mind': 345,
#  'either': 346,
#  'lessons': 347,
#  'word': 348,
#  'name': 349,
#  'else': 350,
#  'sight': 351,
#  'walked': 352,
#  'small': 353,
#  'opened': 354,
#  'those': 355,
#  'bottle': 356,
#  'children': 357,
#  'child': 358,
#  'foot': 359,
#  'yourself': 360,
#  'gloves': 361,
#  'fan': 362,
#  'queer': 363,
#  'everything': 364,
#  'youd': 365,
#  'offended': 366,
#  'creatures': 367,
#  'explain': 368,
#  'rest': 369,
#  'mean': 370,
#  'mouth': 371,
#  'turn': 372,
#  'repeated': 373,
#  'footman': 374,
#  'remarked': 375,
#  'remark': 376,
#  'soldiers': 377,
#  'witness': 378,
#  'pig': 379,
#  'queens': 380,
#  'story': 381,
#  'coming': 382,
#  'couldnt': 383,
#  'answer': 384,
#  'matter': 385,
#  'hall': 386,
#  'glass': 387,
#  'key': 388,
#  'rate': 389,
#  'few': 390,
#  'waiting': 391,
#  'hold': 392,
#  'leave': 393,
#  'against': 394,
#  'want': 395,
#  'help': 396,
#  'different': 397,
#  'tail': 398,
#  'conversation': 399,
#  'birds': 400,
#  'continued': 401,
#  'believe': 402,
#  'call': 403,
#  'angrily': 404,
#  'shook': 405,
#  'does': 406,
#  'reason': 407,
#  'together': 408,
#  'shouted': 409,
#  'timidly': 410,
#  'serpent': 411,
#  'puzzled': 412,
#  'interrupted': 413,
#  'knave': 414,
#  'join': 415,
#  'pepper': 416,
#  'lobster': 417,
#  'tarts': 418,
#  'evidence': 419,
#  'sister': 420,
#  'feel': 421,
#  'making': 422,
#  'watch': 423,
#  'slowly': 424,
#  'happen': 425,
#  'noticed': 426,
#  'top': 427,
#  'opportunity': 428,
#  'itll': 429,
#  'seem': 430,
#  'dry': 431,
#  'fact': 432,
#  'followed': 433,
#  'lying': 434,
#  'work': 435,
#  'ready': 436,
#  'hard': 437,
#  'changed': 438,
#  'mine': 439,
#  'five': 440,
#  'live': 441,
#  'play': 442,
#  'hadnt': 443,
#  'beg': 444,
#  'our': 445,
#  'eagerly': 446,
#  'sit': 447,
#  'party': 448,
#  'meaning': 449,
#  'running': 450,
#  'everybody': 451,
#  'exactly': 452,
#  'nobody': 453,
#  'window': 454,
#  'least': 455,
#  'place': 456,
#  'appeared': 457,
#  'each': 458,
#  'mushroom': 459,
#  'havent': 460,
#  'most': 461,
#  'nose': 462,
#  'asleep': 463,
#  'hearts': 464,
#  'twinkle': 465,
#  'gardeners': 466,
#  'moral': 467,
#  'whiting': 468,
#  'tired': 469,
#  'book': 470,
#  'world': 471,
#  'deep': 472,
#  'somebody': 473,
#  'fall': 474,
#  'listen': 475,
#  'manage': 476,
#  'begun': 477,
#  'dream': 478,
#  'middle': 479,
#  'wondering': 480,
#  'golden': 481,
#  'open': 482,
#  'larger': 483,
#  'bright': 484,
#  'happened': 485,
#  'neck': 486,
#  'drink': 487,
#  'feeling': 488,
#  'generally': 489,
#  'eye': 490,
#  'surprised': 491,
#  'shoes': 492,
#  'myself': 493,
#  'kind': 494,
#  'nonsense': 495,
#  'distance': 496,
#  'sir': 497,
#  'hair': 498,
#  'goes': 499,
#  'shes': 500,
#  'repeat': 501,
#  'learn': 502,
#  'frightened': 503,
#  'chin': 504,
#  'william': 505,
#  'history': 506,
#  'fetch': 507,
#  'lory': 508,
#  'important': 509,
#  'has': 510,
#  'trial': 511,
#  'others': 512,
#  'stood': 513,
#  'grown': 514,
#  'business': 515,
#  'wood': 516,
#  'trees': 517,
#  'isnt': 518,
#  'draw': 519,
#  'silent': 520,
#  'cheshire': 521,
#  'pleased': 522,
#  'song': 523,
#  'hedgehog': 524,
#  'lobsters': 525,
#  'soooop': 526,
#  'slates': 527,
#  'adventures': 528,
#  'stupid': 529,
#  'trouble': 530,
#  'late': 531,
#  'fell': 532,
#  'four': 533,
#  'nice': 534,
#  'written': 535,
#  'leaves': 536,
#  'jumped': 537,
#  'roof': 538,
#  'inches': 539,
#  'marked': 540,
#  'forgotten': 541,
#  'almost': 542,
#  'ten': 543,
#  'croquet': 544,
#  'english': 545,
#  'shant': 546,
#  'stop': 547,
#  'himself': 548,
#  'times': 549,
#  'seven': 550,
#  'grin': 551,
#  'understand': 552,
#  'sentence': 553,
#  'pardon': 554,
#  'trembling': 555,
#  'subject': 556,
#  'youll': 557,
#  'politely': 558,
#  'melancholy': 559,
#  'liked': 560,
#  'chorus': 561,
#  'executed': 562,
#  'broken': 563,
#  'full': 564,
#  'write': 565,
#  'loud': 566,
#  'sharp': 567,
#  'puppy': 568,
#  'arms': 569,
#  'father': 570,
#  'stand': 571,
#  'youth': 572,
#  'sleep': 573,
#  'youve': 574,
#  'sneezing': 575,
#  'between': 576,
#  'told': 577,
#  'ear': 578,
#  'wow': 579,
#  'dreadfully': 580,
#  'sing': 581,
#  'exclaimed': 582,
#  'breadandbutter': 583,
#  'tale': 584,
#  'turtles': 585,
#  'quadrille': 586,
#  'twice': 587,
#  'hot': 588,
#  'sleepy': 589,
#  'across': 590,
#  'curiosity': 591,
#  'passed': 592,
#  'home': 593,
#  'likely': 594,
#  'aloud': 595,
#  'walk': 596,
#  'new': 597,
#  'asking': 598,
#  'sometimes': 599,
#  'walking': 600,
#  'ears': 601,
#  'sadly': 602,
#  'along': 603,
#  'shut': 604,
#  'simple': 605,
#  'cut': 606,
#  'finger': 607,
#  'nervous': 608,
#  'altogether': 609,
#  'fancy': 610,
#  'remembered': 611,
#  'happens': 612,
#  'pair': 613,
#  'nine': 614,
#  'until': 615,
#  'kid': 616,
#  'dropped': 617,
#  'usual': 618,
#  'morning': 619,
#  'ah': 620,
#  'lets': 621,
#  'wrong': 622,
#  'sounded': 623,
#  'strange': 624,
#  'seems': 625,
#  'stay': 626,
#  'sudden': 627,
#  'case': 628,
#  'number': 629,
#  'swam': 630,
#  'nearer': 631,
#  'speaking': 632,
#  'animals': 633,
#  'shrill': 634,
#  'angry': 635,
#  'crowded': 636,
#  'notice': 637,
#  'whats': 638,
#  'prizes': 639,
#  'pocket': 640,
#  'dare': 641,
#  'confusion': 642,
#  'reply': 643,
#  'finish': 644,
#  'impatiently': 645,
#  'sighed': 646,
#  'temper': 647,
#  'young': 648,
#  'moved': 649,
#  'swim': 650,
#  'doing': 651,
#  'direction': 652,
#  'interesting': 653,
#  'chimney': 654,
#  'become': 655,
#  'shouldnt': 656,
#  'taking': 657,
#  'shriek': 658,
#  'drew': 659,
#  'instantly': 660,
#  'surprise': 661,
#  'lizard': 662,
#  'height': 663,
#  'quietly': 664,
#  'hookah': 665,
#  'man': 666,
#  'often': 667,
#  'eggs': 668,
#  'tree': 669,
#  'meant': 670,
#  'waving': 671,
#  'treacle': 672,
#  'piece': 673,
#  'faces': 674,
#  'procession': 675,
#  'rule': 676,
#  'pack': 677,
#  'knee': 678,
#  'whispered': 679,
#  'flamingo': 680,
#  'executioner': 681,
#  'tis': 682,
#  'school': 683,
#  'jurymen': 684,
#  'rabbithole': 685,
#  'caucusrace': 686,
#  'croquetground': 687,
#  'pictures': 688,
#  'worth': 689,
#  'natural': 690,
#  'sides': 691,
#  'fear': 692,
#  'managed': 693,
#  'theyll': 694,
#  'true': 695,
#  'fallen': 696,
#  'earth': 697,
#  'several': 698,
#  'sound': 699,
#  'girl': 700,
#  'miss': 701,
#  'bats': 702,
#  'passage': 703,
#  'except': 704,
#  'tiny': 705,
#  'alas': 706,
#  'second': 707,
#  'led': 708,
#  'shoulders': 709,
#  'paper': 710,
#  'taught': 711,
#  'deeply': 712,
#  'ventured': 713,
#  'reach': 714,
#  'sharply': 715,
#  'severely': 716,
#  'box': 717,
#  'person': 718,
#  'care': 719,
#  'boots': 720,
#  'savage': 721,
#  'violently': 722,
#  'today': 723,
#  'age': 724,
#  'mabel': 725,
#  'besides': 726,
#  'puzzling': 727,
#  'twelve': 728,
#  'capital': 729,
#  'alone': 730,
#  'rabbits': 731,
#  'shrinking': 732,
#  'escape': 733,
#  'water': 734,
#  'digging': 735,
#  'french': 736,
#  'paws': 737,
#  'dogs': 738,
#  'says': 739,
#  'pale': 740,
#  'duck': 741,
#  'uncomfortable': 742,
#  'argument': 743,
#  'wanted': 744,
#  'frowning': 745,
#  'means': 746,
#  'solemnly': 747,
#  'pointing': 748,
#  'confused': 749,
#  'thimble': 750,
#  'short': 751,
#  'bowed': 752,
#  'judge': 753,
#  'breath': 754,
#  'tongue': 755,
#  'since': 756,
#  'vanished': 757,
#  'mary': 758,
#  'ann': 759,
#  'run': 760,
#  'theyd': 761,
#  'chance': 762,
#  'ordered': 763,
#  'answered': 764,
#  'outside': 765,
#  'yer': 766,
#  'honour': 767,
#  'sounds': 768,
#  'hearing': 769,
#  'fellow': 770,
#  'thank': 771,
#  'dead': 772,
#  'doubt': 773,
#  'lay': 774,
#  'crowd': 775,
#  'held': 776,
#  'guineapigs': 777,
#  'plan': 778,
#  'difficulty': 779,
#  'stick': 780,
#  'grass': 781,
#  'perfectly': 782,
#  'none': 783,
#  'stuff': 784,
#  'decidedly': 785,
#  'thoughtfully': 786,
#  'green': 787,
#  'screamed': 788,
#  'indignantly': 789,
#  'taken': 790,
#  'sky': 791,
#  'lives': 792,
#  'otherwise': 793,
#  'ground': 794,
#  'dish': 795,
#  'days': 796,
#  'kitchen': 797,
#  'jumping': 798,
#  'carried': 799,
#  'hours': 800,
#  'busily': 801,
#  'beat': 802,
#  'verse': 803,
#  'creature': 804,
#  'grunted': 805,
#  'less': 806,
#  'fast': 807,
#  'crumbs': 808,
#  'shoulder': 809,
#  'twinkling': 810,
#  'sigh': 811,
#  'bottom': 812,
#  'begins': 813,
#  'm': 814,
#  'rosetree': 815,
#  'consider': 816,
#  'arches': 817,
#  'players': 818,
#  'sobs': 819,
#  'porpoise': 820,
#  'beauootiful': 821,
#  'trials': 822,
#  'jurybox': 823,
#  'jurors': 824,
#  'writing': 825,
#  'officers': 826,
#  'suppressed': 827,
#  'verses': 828,
#  'wonderland': 829,
#  'ii': 830,
#  'advice': 831,
#  'teaparty': 832,
#  'stole': 833,
#  'peeped': 834,
#  'reading': 835,
#  'considering': 836,
#  'nor': 837,
#  'dark': 838,
#  'filled': 839,
#  'stairs': 840,
#  'miles': 841,
#  'somewhere': 842,
#  'knowledge': 843,
#  'grand': 844,
#  'funny': 845,
#  'listening': 846,
#  'shell': 847,
#  'hope': 848,
#  'mice': 849,
#  'catch': 850,
#  'bat': 851,
#  'hurt': 852,
#  'lost': 853,
#  'corner': 854,
#  'whiskers': 855,
#  'longer': 856,
#  'hanging': 857,
#  'delight': 858,
#  'telescope': 859,
#  'outoftheway': 860,
#  'impossible': 861,
#  'hoping': 862,
#  'rules': 863,
#  'poison': 864,
#  'certain': 865,
#  'later': 866,
#  'finding': 867,
#  'further': 868,
#  'candle': 869,
#  'decided': 870,
#  'possibly': 871,
#  'legs': 872,
#  'bring': 873,
#  'fond': 874,
#  'cake': 875,
#  'smaller': 876,
#  'holding': 877,
#  'remained': 878,
#  'expecting': 879,
#  'dull': 880,
#  'opening': 881,
#  'dears': 882,
#  'directions': 883,
#  'love': 884,
#  'cry': 885,
#  'pattering': 886,
#  'muttering': 887,
#  'timid': 888,
#  'yesterday': 889,
#  'night': 890,
#  'sorts': 891,
#  'doth': 892,
#  'crossed': 893,
#  'hoarse': 894,
#  'spread': 895,
#  'gently': 896,
#  'putting': 897,
#  'guess': 898,
#  'cause': 899,
#  'worse': 900,
#  'slipped': 901,
#  'general': 902,
#  'o': 903,
#  'notion': 904,
#  'show': 905,
#  'fire': 906,
#  'washing': 907,
#  'throw': 908,
#  'passion': 909,
#  'shore': 910,
#  'eaglet': 911,
#  'fur': 912,
#  'sulky': 913,
#  'allow': 914,
#  'crown': 915,
#  'move': 916,
#  'pressed': 917,
#  'handed': 918,
#  'gravely': 919,
#  'speech': 920,
#  'cheered': 921,
#  'grave': 922,
#  'solemn': 923,
#  'noise': 924,
#  'choked': 925,
#  'whisper': 926,
#  'sad': 927,
#  'sighing': 928,
#  'fury': 929,
#  'met': 930,
#  'attending': 931,
#  'pleaded': 932,
#  'easily': 933,
#  'joined': 934,
#  'pity': 935,
#  'crab': 936,
#  'particular': 937,
#  'venture': 938,
#  'carefully': 939,
#  'remarking': 940,
#  'suit': 941,
#  'mentioned': 942,
#  'guessed': 943,
#  'hunting': 944,
#  'mistake': 945,
#  'plate': 946,
#  'knocking': 947,
#  'real': 948,
#  'floor': 949,
#  'effect': 950,
#  'elbow': 951,
#  'whatever': 952,
#  'stopped': 953,
#  'forgetting': 954,
#  'bills': 955,
#  'em': 956,
#  'below': 957,
#  'master': 958,
#  'kick': 959,
#  'above': 960,
#  'sense': 961,
#  'moving': 962,
#  'cakes': 963,
#  'paw': 964,
#  'hungry': 965,
#  'picked': 966,
#  'edge': 967,
#  'immediately': 968,
#  'folded': 969,
#  'confusing': 970,
#  'brought': 971,
#  'remarks': 972,
#  'pray': 973,
#  'questions': 974,
#  'free': 975,
#  'shaking': 976,
#  'succeeded': 977,
#  'serpents': 978,
#  'girls': 979,
#  'tasted': 980,
#  'yours': 981,
#  'settled': 982,
#  'pieces': 983,
#  'nibbling': 984,
#  'bringing': 985,
#  'livery': 986,
#  'considered': 987,
#  'loudly': 988,
#  'letter': 989,
#  'order': 990,
#  'staring': 991,
#  'howling': 992,
#  'instance': 993,
#  'repeating': 994,
#  'hes': 995,
#  'nursing': 996,
#  'courage': 997,
#  'grinned': 998,
#  'growl': 999,
#  'faster': 1000,
#  ...}

# %%
total_vocab = len(tokenizer.word_index) + 1
total_vocab
# Out:
# 2758

# %%
# # Convert words to sequences
# sequences = []
# words = text.split()
# for i in range(1, len(words)):
#     sequence = words[:i+1]  # Create input-output pairs
#     sequences.append(sequence)

# %%
# # Convert words to numerical values
# # Handle unknown words by replacing them with a default value (e.g., 0)
# sequences = [[tokenizer.word_index.get(word, 0) for word in seq] for seq in sequences]

# %%
# sequences

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenize and create sequences with the tokenizer
sequences = tokenizer.texts_to_sequences([text])[0]

# Define sequence length
seq_length = 50

# Generate input-output pairs
input_sequences = []
output_words = []

for i in range(seq_length, len(sequences)):
    input_seq = sequences[i-seq_length:i]  # Sequence of words as input
    output_word = sequences[i]  # The next word to predict
    input_sequences.append(input_seq)
    output_words.append(output_word)

# Pad sequences to ensure they all have the same length
X = pad_sequences(input_sequences, maxlen=seq_length)

# Convert output words into numpy array
import numpy as np
y = np.array(output_words)

# %%
X.shape
# Out:
# (26435, 50)

# %%
y.shape
# Out:
# (26435,)

# %%
# Convert y to one-hot encoded format
y = tensorflow.keras.utils.to_categorical(y, num_classes=len(tokenizer.word_index) + 1)

# %%
y.shape
# Out:
# (26435, 2758)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (26435, 50)
# y shape: (26435, 2758)

# %%
print("✅ Text preprocessing complete! Ready for LSTM training.")
# Out:
# ✅ Text preprocessing complete! Ready for LSTM training.

# %% [markdown]
# # Building the LSTM Model

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding,Input, Dropout

# %%
X.shape[1]
# Out:
# 50

# %%
total_vocab + 1
# Out:
# 2759

# %%
model = Sequential()

model.add(Input(shape=(X.shape[1],)))
model.add(Embedding(input_dim=total_vocab+1,output_dim=50))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(total_vocab,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 50, 50)              │         137,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          29,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2758)                │         179,270 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 346,660 (1.32 MB)
#  Trainable params: 346,660 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X,y,epochs=100,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.0512 - loss: 6.5518 - val_accuracy: 0.0847 - val_loss: 6.1618
# Epoch 2/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.0567 - loss: 5.8821 - val_accuracy: 0.0870 - val_loss: 6.1969
# Epoch 3/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.0629 - loss: 5.8118 - val_accuracy: 0.0912 - val_loss: 6.1324
# Epoch 4/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.0719 - loss: 5.6496 - val_accuracy: 0.0949 - val_loss: 6.0738
# Epoch 5/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.0869 - loss: 5.4464 - val_accuracy: 0.1037 - val_loss: 6.0432
# Epoch 6/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.1024 - loss: 5.2844 - val_accuracy: 0.1141 - val_loss: 6.0064
# Epoch 7/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.1161 - loss: 5.1275 - val_accuracy: 0.1178 - val_loss: 6.0036
# Epoch 8/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.1278 - loss: 4.9958 - val_accuracy: 0.1199 - val_loss: 5.9939
# Epoch 9/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.1380 - loss: 4.8546 - val_accuracy: 0.1218 - val_loss: 6.0363
# Epoch 10/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.1456 - loss: 4.7390 - val_accuracy: 0.1286 - val_loss: 6.0742
# Epoch 11/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.1543 - loss: 4.6400 - val_accuracy: 0.1307 - val_loss: 6.1127
# Epoch 12/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1564 - loss: 4.5548 - val_accuracy: 0.1296 - val_loss: 6.1629
# Epoch 13/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.1695 - loss: 4.4385 - val_accuracy: 0.1282 - val_loss: 6.2260
# Epoch 14/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1712 - loss: 4.3324 - val_accuracy: 0.1299 - val_loss: 6.2793
# Epoch 15/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1852 - loss: 4.2470 - val_accuracy: 0.1320 - val_loss: 6.3262
# Epoch 16/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1825 - loss: 4.1924 - val_accuracy: 0.1330 - val_loss: 6.3864
# Epoch 17/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.1906 - loss: 4.1061 - val_accuracy: 0.1360 - val_loss: 6.4577
# Epoch 18/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.2024 - loss: 4.0037 - val_accuracy: 0.1341 - val_loss: 6.5171
# Epoch 19/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2065 - loss: 3.9365 - val_accuracy: 0.1335 - val_loss: 6.5832
# Epoch 20/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2118 - loss: 3.8599 - val_accuracy: 0.1301 - val_loss: 6.6466
# Epoch 21/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2243 - loss: 3.7843 - val_accuracy: 0.1311 - val_loss: 6.7265
# Epoch 22/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.2328 - loss: 3.7007 - val_accuracy: 0.1307 - val_loss: 6.7721
# Epoch 23/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.2408 - loss: 3.6372 - val_accuracy: 0.1262 - val_loss: 6.8436
# Epoch 24/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2435 - loss: 3.5929 - val_accuracy: 0.1248 - val_loss: 6.8953
# Epoch 25/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.2543 - loss: 3.5183 - val_accuracy: 0.1245 - val_loss: 6.9600
# Epoch 26/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2677 - loss: 3.4526 - val_accuracy: 0.1280 - val_loss: 7.0221
# Epoch 27/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2734 - loss: 3.3843 - val_accuracy: 0.1190 - val_loss: 7.0994
# Epoch 28/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2838 - loss: 3.3286 - val_accuracy: 0.1229 - val_loss: 7.1514
# Epoch 29/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2834 - loss: 3.2821 - val_accuracy: 0.1209 - val_loss: 7.2260
# Epoch 30/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3027 - loss: 3.2012 - val_accuracy: 0.1171 - val_loss: 7.2835
# Epoch 31/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3112 - loss: 3.1642 - val_accuracy: 0.1142 - val_loss: 7.3382
# Epoch 32/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3151 - loss: 3.1180 - val_accuracy: 0.1137 - val_loss: 7.3966
# Epoch 33/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3221 - loss: 3.0660 - val_accuracy: 0.1156 - val_loss: 7.4750
# Epoch 34/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3285 - loss: 3.0322 - val_accuracy: 0.1124 - val_loss: 7.5075
# Epoch 35/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3353 - loss: 2.9710 - val_accuracy: 0.1135 - val_loss: 7.5635
# Epoch 36/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3437 - loss: 2.9224 - val_accuracy: 0.1141 - val_loss: 7.6131
# Epoch 37/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3492 - loss: 2.8890 - val_accuracy: 0.1156 - val_loss: 7.6678
# Epoch 38/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3604 - loss: 2.8449 - val_accuracy: 0.1108 - val_loss: 7.7077
# Epoch 39/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3706 - loss: 2.8069 - val_accuracy: 0.1122 - val_loss: 7.7583
# Epoch 40/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3755 - loss: 2.7542 - val_accuracy: 0.1125 - val_loss: 7.8023
# Epoch 41/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.3805 - loss: 2.7204 - val_accuracy: 0.1116 - val_loss: 7.8520
# Epoch 42/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3872 - loss: 2.6960 - val_accuracy: 0.1114 - val_loss: 7.9366
# Epoch 43/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3937 - loss: 2.6549 - val_accuracy: 0.1093 - val_loss: 7.9560
# Epoch 44/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3941 - loss: 2.6361 - val_accuracy: 0.1069 - val_loss: 8.0065
# Epoch 45/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4058 - loss: 2.5975 - val_accuracy: 0.1082 - val_loss: 8.0666
# Epoch 46/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4019 - loss: 2.5655 - val_accuracy: 0.1093 - val_loss: 8.1112
# Epoch 47/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4168 - loss: 2.5361 - val_accuracy: 0.1097 - val_loss: 8.1580
# Epoch 48/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4233 - loss: 2.5013 - val_accuracy: 0.1086 - val_loss: 8.1984
# Epoch 49/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.4217 - loss: 2.4688 - val_accuracy: 0.1082 - val_loss: 8.2599
# Epoch 50/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4295 - loss: 2.4368 - val_accuracy: 0.1091 - val_loss: 8.3023
# Epoch 51/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4373 - loss: 2.4038 - val_accuracy: 0.1065 - val_loss: 8.3330
# Epoch 52/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4451 - loss: 2.3664 - val_accuracy: 0.1099 - val_loss: 8.3728
# Epoch 53/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4453 - loss: 2.3704 - val_accuracy: 0.1021 - val_loss: 8.4399
# Epoch 54/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4468 - loss: 2.3422 - val_accuracy: 0.1065 - val_loss: 8.4795
# Epoch 55/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4570 - loss: 2.3097 - val_accuracy: 0.1074 - val_loss: 8.5166
# Epoch 56/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4611 - loss: 2.2912 - val_accuracy: 0.1074 - val_loss: 8.5570
# Epoch 57/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4533 - loss: 2.2773 - val_accuracy: 0.1067 - val_loss: 8.6031
# Epoch 58/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4688 - loss: 2.2305 - val_accuracy: 0.1038 - val_loss: 8.6494
# Epoch 59/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4774 - loss: 2.2140 - val_accuracy: 0.1046 - val_loss: 8.7013
# Epoch 60/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4691 - loss: 2.2312 - val_accuracy: 0.1025 - val_loss: 8.7407
# Epoch 61/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4761 - loss: 2.2044 - val_accuracy: 0.1071 - val_loss: 8.7670
# Epoch 62/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4776 - loss: 2.1669 - val_accuracy: 0.1055 - val_loss: 8.8111
# Epoch 63/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4850 - loss: 2.1534 - val_accuracy: 0.1050 - val_loss: 8.8520
# Epoch 64/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4844 - loss: 2.1431 - val_accuracy: 0.1021 - val_loss: 8.8857
# Epoch 65/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4979 - loss: 2.1097 - val_accuracy: 0.1040 - val_loss: 8.9301
# Epoch 66/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4991 - loss: 2.0755 - val_accuracy: 0.1025 - val_loss: 8.9565
# Epoch 67/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5009 - loss: 2.0734 - val_accuracy: 0.1063 - val_loss: 8.9917
# Epoch 68/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4998 - loss: 2.0609 - val_accuracy: 0.1008 - val_loss: 9.0584
# Epoch 69/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5039 - loss: 2.0294 - val_accuracy: 0.1001 - val_loss: 9.0913
# Epoch 70/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5140 - loss: 2.0082 - val_accuracy: 0.1010 - val_loss: 9.1203
# Epoch 71/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5144 - loss: 1.9782 - val_accuracy: 0.1002 - val_loss: 9.1694
# Epoch 72/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5078 - loss: 2.0020 - val_accuracy: 0.0997 - val_loss: 9.2066
# Epoch 73/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5107 - loss: 1.9860 - val_accuracy: 0.0968 - val_loss: 9.2101
# Epoch 74/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5182 - loss: 1.9512 - val_accuracy: 0.1006 - val_loss: 9.2778
# Epoch 75/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5242 - loss: 1.9394 - val_accuracy: 0.1001 - val_loss: 9.3060
# Epoch 76/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5210 - loss: 1.9346 - val_accuracy: 0.0970 - val_loss: 9.3237
# Epoch 77/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5357 - loss: 1.9143 - val_accuracy: 0.0989 - val_loss: 9.3858
# Epoch 78/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5290 - loss: 1.9002 - val_accuracy: 0.1008 - val_loss: 9.4116
# Epoch 79/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5335 - loss: 1.8766 - val_accuracy: 0.0978 - val_loss: 9.4431
# Epoch 80/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5370 - loss: 1.8640 - val_accuracy: 0.0987 - val_loss: 9.4766
# Epoch 81/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5355 - loss: 1.8787 - val_accuracy: 0.0936 - val_loss: 9.5141
# Epoch 82/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5407 - loss: 1.8482 - val_accuracy: 0.0978 - val_loss: 9.5381
# Epoch 83/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.5482 - loss: 1.8241 - val_accuracy: 0.0985 - val_loss: 9.5821
# Epoch 84/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5450 - loss: 1.8086 - val_accuracy: 0.0934 - val_loss: 9.5820
# Epoch 85/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5532 - loss: 1.8010 - val_accuracy: 0.0961 - val_loss: 9.6452
# Epoch 86/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5581 - loss: 1.7799 - val_accuracy: 0.0978 - val_loss: 9.6839
# Epoch 87/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5539 - loss: 1.7946 - val_accuracy: 0.0961 - val_loss: 9.7086
# Epoch 88/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.5565 - loss: 1.7747 - val_accuracy: 0.0972 - val_loss: 9.7713
# Epoch 89/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5476 - loss: 1.7816 - val_accuracy: 0.0936 - val_loss: 9.7985
# Epoch 90/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5604 - loss: 1.7526 - val_accuracy: 0.0978 - val_loss: 9.8139
# Epoch 91/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5647 - loss: 1.7310 - val_accuracy: 0.0991 - val_loss: 9.8338
# Epoch 92/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5663 - loss: 1.7247 - val_accuracy: 0.0959 - val_loss: 9.8610
# Epoch 93/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5651 - loss: 1.7292 - val_accuracy: 0.1006 - val_loss: 9.9211
# Epoch 94/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5686 - loss: 1.6983 - val_accuracy: 0.0989 - val_loss: 9.9309
# Epoch 95/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5659 - loss: 1.6971 - val_accuracy: 0.0955 - val_loss: 9.9612
# Epoch 96/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5718 - loss: 1.6897 - val_accuracy: 0.1014 - val_loss: 9.9937
# Epoch 97/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5761 - loss: 1.6684 - val_accuracy: 0.0999 - val_loss: 9.9874
# Epoch 98/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5756 - loss: 1.6845 - val_accuracy: 0.0944 - val_loss: 10.0553
# Epoch 99/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5812 - loss: 1.6484 - val_accuracy: 0.0940 - val_loss: 10.0572
# Epoch 100/100
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5773 - loss: 1.6623 - val_accuracy: 0.0970 - val_loss: 10.0934

# %% [markdown]
# # Model Prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

def generate_text(seed_text, model, tokenizer, seq_length, num_words=50, words_per_line=10):
    output_text = seed_text
    generated_words = []  # Store words separately for formatting

    for _ in range(num_words):
        # Tokenize and pad the input sequence
        encoded = tokenizer.texts_to_sequences([output_text])[0]
        encoded = pad_sequences([encoded], maxlen=seq_length, padding='pre')

        # Predict the next word
        predicted_index = np.argmax(model.predict(encoded, verbose=0), axis=-1)[0]

        # Convert index to word
        word = tokenizer.index_word.get(predicted_index, '')  # Default to empty if not found
        if not word:
            break  # Stop if no valid word is found

        generated_words.append(word)
        output_text += ' ' + word

    # Format the output in multiple lines
    formatted_text = ""
    for i in range(0, len(generated_words), words_per_line):
        formatted_text += " ".join(generated_words[i:i+words_per_line]) + "\n"

    return formatted_text.strip()  # Remove trailing newlines

# Get input from the user
seed_text = input("Enter a starting phrase: ")

# Generate and display the output
generated_text = generate_text(seed_text, model, tokenizer, seq_length, num_words=50)

print("\n📝 **Generated Story** 📝\n")
print(generated_text)
# Out:
# Enter a starting phrase: Who in the world am I?"
#
# 📝 **Generated Story** 📝
#
# can do to be no use said to the things
# went on without attending to her if you had said
# the hatter i can herself out of the window and
# after a few minutes it was looking for the fan
# and gloves and the baby was howling alternately without a

# %%
# User_Input Example
'''🔹
Fantasy / Wonderland Style

"Alice stepped through the door and found herself in"
"The white rabbit looked at Alice and said,"
"In the middle of the forest, Alice discovered a"
"The Mad Hatter grinned and whispered,"
"Alice picked up the strange golden key and"

🔹 Mystery / Adventure

"The moment Alice touched the mirror, she felt"
"The Queen of Hearts turned to Alice and shouted,"
"Alice followed the Cheshire Cat through the fog and"
"There was a hidden note on the teacup that said,"
"Alice opened the mysterious book and saw"

'''
# Out:
# '🔹 \nFantasy / Wonderland Style\n\n"Alice stepped through the door and found herself in"\n"The white rabbit looked at Alice and said,"\n"In the middle of the forest, Alice discovered a"\n"The Mad Hatter grinned and whispered,"\n"Alice picked up the strange golden key and"\n\n🔹 Mystery / Adventure\n\n"The moment Alice touched the mirror, she felt"\n"The Queen of Hearts turned to Alice and shouted,"\n"Alice followed the Cheshire Cat through the fog and"\n"There was a hidden note on the teacup that said,"\n"Alice opened the mysterious book and saw"\n\n'
